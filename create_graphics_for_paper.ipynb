# %%
import torch
import matplotlib.pyplot as plt

# %%
from qubit_sim.noise_gen_classes import OneOnFNoiseWithBumpNoiseGenerator

from data_gen.data_gen_sim_constants import (
    TOTAL_TIME,
    NUM_TIME_STEPS,
)

# %%
plt.rc("font", family="serif", serif="cm10")
plt.rc("text", usetex=True)
font_size = 20
plt.rcParams.update({"font.size": font_size})

# %%
frequencies = torch.fft.fftfreq(
    n=NUM_TIME_STEPS,
    d=TOTAL_TIME / NUM_TIME_STEPS,
)

# %%
one_on_f_noise_gen = OneOnFNoiseWithBumpNoiseGenerator(
    total_num_examples=1,
    mu=100.0,
    sigma=5,
    height=0.5,
    threshold_freq=1000.0,
)

# %%
spectral_density = one_on_f_noise_gen.sqrt_scaled_spectral_density

# %%
plt.figure(figsize=(10, 5))
plt.plot(frequencies[: NUM_TIME_STEPS // 2], spectral_density)
plt.xlabel("Frequency Bin")
plt.ylabel("Scaled Amplitude Spectral Density")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend()
plt.savefig(
    "./diagram_pictures/one_on_f_noise_with_b_spectral_density.png",
    dpi=500,
    bbox_inches="tight",
)
# Out:
# /tmp/ipykernel_4730/3141265957.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
average_noise = one_on_f_noise_gen.precomputed_noise[0, :, :].mean(dim=-1)

# %%
plt.figure(figsize=(10, 5))
plt.plot(average_noise[: NUM_TIME_STEPS // 2])
plt.xlabel("Time interval (t)")
plt.ylabel(r"Noise Value ($\beta_{j}(t)$)")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend()
plt.savefig(
    "./diagram_pictures/one_on_f_with_b_noise.png", dpi=500, bbox_inches="tight"
)
# Out:
# /tmp/ipykernel_4730/1506314995.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
one_on_f_noise_gen = OneOnFNoiseWithBumpNoiseGenerator(
    total_num_examples=1,
    mu=0.0,
    threshold_freq=1000.0,
)

# %%
spectral_density = one_on_f_noise_gen.sqrt_scaled_spectral_density

# %%
plt.figure(figsize=(10, 5))
plt.plot(frequencies[: NUM_TIME_STEPS // 2], spectral_density)
plt.xlabel("Frequency Bin")
plt.ylabel("Scaled Amplitude Spectral Density")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend()
plt.savefig("./diagram_pictures/one_on_f_noise_spectral_density.png", dpi=50, bbox_inches="tight")
# Out:
# /tmp/ipykernel_4730/1636416283.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
average_noise = one_on_f_noise_gen.precomputed_noise[0, :, :].mean(dim=-1)

# %%
plt.figure(figsize=(10, 5))
plt.plot(average_noise[: NUM_TIME_STEPS // 2])
plt.xlabel("Time interval (t)")
plt.ylabel(r"Noise Value ($\beta_{j}(t)$)")
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.legend()
plt.savefig("./diagram_pictures/one_on_f_noise.png", dpi=500, bbox_inches="tight")
# Out:
# /tmp/ipykernel_4730/2636457618.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
